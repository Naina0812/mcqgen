# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
KEY= os.getenv("OPENAI_API_KEY")

# %%
print("KEY:", KEY)
# Out:
# KEY: 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

# %%
llm= ChatOpenAI(openai_api_key=KEY, model="gpt-4-0613", temperature=0.5)
